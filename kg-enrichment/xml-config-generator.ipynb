# %%
# Create/Load the config xml template
# extract all classes and their properties from dbpedia ontology
# For each class find coverage of each property
# write config file for each class
    # write properties with coverage higher than set threshold

# %%
# Imports
import xml.etree.ElementTree as ET
from SPARQLWrapper import SPARQLWrapper, JSON
import time, os, re, copy
from xml.dom import minidom

# %%
# Read template xml file to a string
sample_xml = './limes_config_template.xml'
sample_file = ET.parse(sample_xml)

# %%
# Sparql endpoints
sparql_en = SPARQLWrapper(endpoint="http://porque.cs.upb.de:8890/sparql", defaultGraph="http://www.upb.de/en-dbp2016-10")
sparql_de = SPARQLWrapper(endpoint="http://porque.cs.upb.de:8890/sparql", defaultGraph="http://www.upb.de/de-dbp2016-10")
sparql_fr = SPARQLWrapper(endpoint="http://porque.cs.upb.de:8890/sparql", defaultGraph="http://www.upb.de/fr-dbp2016-10")
sparql_es = SPARQLWrapper(endpoint="http://porque.cs.upb.de:8890/sparql", defaultGraph="http://www.upb.de/es-dbp2016-10")

sparql_map = {
    'en': sparql_en,
    'de': sparql_de,
    'es': sparql_es,
    'fr': sparql_fr
}

# %%
# SPARQL - for each class find all its properties ond the number of times it appeared in its instances
propcount_sparql = '''
SELECT ?prop (count(?prop) as ?propcount) WHERE
{
# ?res a <%s> .
# ?res ?prop ?obj .
# ?prop <http://www.w3.org/2000/01/rdf-schema#domain> <%s> .
FILTER STRSTARTS( str(?prop), "http://dbpedia.org/ontology/" )
}
GROUP BY ?prop
'''
# SPARQL - for each class count the number of instances it has
rescount_sparql = '''
select ?class (count(?res) as ?instancecount) where {
# ?res a ?class .
FILTER STRSTARTS( str(?class), "http://dbpedia.org/ontology/" )
} 
GROUP BY ?class
'''

restriction_tmplt_x = '?x a dbo:%s'
restriction_tmplt_y = '?y a dbo:%s'

# %%
# Extract instance counts for all classes
crm_lang_map = dict()
for lang in sparql_map.keys():
    sparql_ln = sparql_map[lang]
    class_rescount_map = dict()
    
    sparql_ln.setQuery(rescount_sparql)
    sparql_ln.setReturnFormat(JSON)
    results = sparql_ln.query().convert()

    for result in results["results"]["bindings"]:
        classUri = result["class"]["value"]
        instanceCount = result["instancecount"]["value"]
        class_rescount_map[classUri] = instanceCount
    crm_lang_map[lang] = class_rescount_map
    print(lang,'class->instance-count map size:',len(class_rescount_map))
# Out:
# en class->instance-count map size: 421
# de class->instance-count map size: 138
# es class->instance-count map size: 158
# fr class->instance-count map size: 199

# %%
# Extract property counts for all classes and divide them by instance counts to get coverage
class_rescount_map = crm_lang_map['en']
class_propcov_map = dict()
xml_map = dict()
for classUri in class_rescount_map.keys():
    # ignore classes with zero instances
    if class_rescount_map[classUri] == 0:
        continue
    print('Querying for class', classUri)
    class_propcov_map[classUri] = dict()
    # Run query 
    sparql_en.setQuery(propcount_sparql%(classUri, classUri))
    sparql_en.setReturnFormat(JSON)
    results = sparql_en.query().convert()
    
    print('Results found:', len(results["results"]["bindings"]))
    propTags = []
    # Adding rdfs label tag by default
    prop_tag = ET.Element('PROPERTY')
    prop_tag.text = 'rdfs:label AS nolang->lowercase'
    propTags.append(prop_tag)
    # this array is just for logging
    propLbls = []
    for result in results["results"]["bindings"]:
        propUri = result["prop"]["value"]
        propCount = result["propcount"]["value"]
        propCov = int(propCount)/int(class_rescount_map[classUri])
        class_propcov_map[classUri][propUri] = propCov
        if(propCov > 0.4):
            # Create Property tags
            prop_tag = ET.Element('PROPERTY')
            # prop_tag.text = '<'+propUri+'>'
            prop_tag.text = 'dbo:' + propUri.split('/')[-1]
            propLbls.append(prop_tag.text)
            propTags.append(prop_tag)
    print('accepted properties:', propLbls)
    if(len(propTags) > 1):
        # Create XML Config
        xml_obj = copy.deepcopy(sample_file)
        # Create restrictions with class URI
        restr_tagx = ET.Element('RESTRICTION')
        restr_tagy = ET.Element('RESTRICTION')
        class_label = classUri.split('/')[-1]
        restr_tagx.text = restriction_tmplt_x%(class_label)
        restr_tagy.text = restriction_tmplt_y%(class_label)
        
        # Find source and target
        source_ele = xml_obj.getroot().find('SOURCE')
        target_ele = xml_obj.getroot().find('TARGET')
        # add source elements
        source_ele.append(restr_tagx)
        source_ele.extend(propTags)
        # add target elements
        target_ele.append(restr_tagy)
        target_ele.extend(propTags)
        # append to xml list
        # print('Position in array:', len(xml_arr))
        xml_map[classUri] = xml_obj
# Out:
# Querying for class http://dbpedia.org/ontology/FootballLeagueSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MusicalWork
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PokerPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RoadJunction
# Results found: 1
# accepted properties: ['dbo:meetingRoad']
# Querying for class http://dbpedia.org/ontology/SkiArea
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MouseGeneLocation
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/EducationalInstitution
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VolleyballPlayer
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SolarEclipse
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RailwayStation
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BowlingLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bay
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AcademicJournal
# Results found: 5
# accepted properties: ['dbo:impactFactor', 'dbo:academicDiscipline', 'dbo:impactFactorAsOf']
# Querying for class http://dbpedia.org/ontology/Activity
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AdministrativeRegion
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AdultActor
# Results found: 1
# accepted properties: ['dbo:numberOfFilms']
# Querying for class http://dbpedia.org/ontology/Aircraft
# Results found: 3
# accepted properties: ['dbo:numberBuilt']
# Querying for class http://dbpedia.org/ontology/Album
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Anime
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Artist
# Results found: 6
# accepted properties: ['dbo:training', 'dbo:field']
# Querying for class http://dbpedia.org/ontology/AustralianRulesFootballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Automobile
# Results found: 7
# accepted properties: ['dbo:bodyStyle', 'dbo:engine', 'dbo:layout', 'dbo:wheelbase', 'dbo:transmission']
# Querying for class http://dbpedia.org/ontology/Band
# Results found: 2
# accepted properties: ['dbo:bandMember', 'dbo:formerBandMember']
# Querying for class http://dbpedia.org/ontology/BaseballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Brewery
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CareerStation
# Results found: 2
# accepted properties: ['dbo:numberOfMatches', 'dbo:numberOfGoals']
# Querying for class http://dbpedia.org/ontology/ClassicalMusicArtist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Cleric
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CollegeCoach
# Results found: 6
# accepted properties: ['dbo:overallRecord']
# Querying for class http://dbpedia.org/ontology/Convention
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Crustacean
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Diocese
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Engineer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Hospital
# Results found: 1
# accepted properties: ['dbo:bedCount']
# Querying for class http://dbpedia.org/ontology/IceHockeyPlayer
# Results found: 6
# accepted properties: ['dbo:shoots']
# Querying for class http://dbpedia.org/ontology/Magazine
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Mammal
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Model
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Mollusca
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Motorcycle
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/NetballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Play
# Results found: 9
# accepted properties: ['dbo:settingOfPlay', 'dbo:premierePlace', 'dbo:premiereDate', 'dbo:characterInPlay', 'dbo:premiereYear']
# Querying for class http://dbpedia.org/ontology/Poem
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RadioProgram
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RoadTunnel
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Sales
# Results found: 5
# accepted properties: ['dbo:numberSold']
# Querying for class http://dbpedia.org/ontology/School
# Results found: 40
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ScreenWriter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Sea
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoapCharacter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoccerManager
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Software
# Results found: 8
# accepted properties: ['dbo:operatingSystem', 'dbo:programmingLanguage', 'dbo:latestReleaseVersion']
# Querying for class http://dbpedia.org/ontology/Stadium
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Star
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TradeUnion
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/University
# Results found: 7
# accepted properties: ['dbo:campus']
# Querying for class http://dbpedia.org/ontology/BaseballSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Archaea
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Event
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HorseTrainer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Valley
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/NCAATeamSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CurlingLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Ligament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/WaterRide
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AmateurBoxer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ArtificialSatellite
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ArtistDiscography
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Artwork
# Results found: 1
# accepted properties: ['dbo:museum']
# Querying for class http://dbpedia.org/ontology/Bodybuilder
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Building
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Continent
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Crater
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Criminal
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Disease
# Results found: 4
# accepted properties: ['dbo:icd10', 'dbo:meshId', 'dbo:icd9']
# Querying for class http://dbpedia.org/ontology/Food
# Results found: 13
# accepted properties: ['dbo:ingredient', 'dbo:ingredientName']
# Querying for class http://dbpedia.org/ontology/Galaxy
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GolfTournament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GridironFootballPlayer
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Insect
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Journalist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Legislature
# Results found: 8
# accepted properties: ['dbo:numberOfMembers', 'dbo:politicalPartyInLegislature', 'dbo:politicalPartyOfLeader', 'dbo:lastElectionDate']
# Querying for class http://dbpedia.org/ontology/MemberOfParliament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Mineral
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Monument
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MusicGenre
# Results found: 4
# accepted properties: ['dbo:musicSubgenre', 'dbo:musicFusionGenre', 'dbo:stylisticOrigin', 'dbo:derivative']
# Querying for class http://dbpedia.org/ontology/NationalFootballLeagueEvent
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Non-ProfitOrganisation
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Philosopher
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Plant
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PowerStation
# Results found: 5
# accepted properties: ['dbo:primaryFuelType', 'dbo:installedCapacity']
# Querying for class http://dbpedia.org/ontology/Publisher
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ReligiousBuilding
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RugbyClub
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RugbyLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Settlement
# Results found: 18
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoccerClub
# Results found: 9
# accepted properties: ['dbo:ground']
# Querying for class http://dbpedia.org/ontology/SoccerPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SpaceStation
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Sport
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SportsTeam
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TennisTournament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BusinessPerson
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ClassicalMusicComposition
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FieldHockeyLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/LawFirm
# Results found: 2
# accepted properties: ['dbo:numberOfOffices', 'dbo:numberOfLawyers']
# Querying for class http://dbpedia.org/ontology/Poet
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Vein
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Asteroid
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GolfCourse
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SnookerWorldRanking
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VoiceActor
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Airline
# Results found: 7
# accepted properties: ['dbo:iataAirlineCode', 'dbo:hubAirport', 'dbo:targetAirport', 'dbo:icaoAirlineCode']
# Querying for class http://dbpedia.org/ontology/AnatomicalStructure
# Results found: 11
# accepted properties: ['dbo:graySubject', 'dbo:grayPage']
# Querying for class http://dbpedia.org/ontology/Animal
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bird
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Boxer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ClubMoss
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ComedyGroup
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Company
# Results found: 11
# accepted properties: ['dbo:industry']
# Querying for class http://dbpedia.org/ontology/Embryology
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FigureSkater
# Results found: 5
# accepted properties: ['dbo:formerPartner', 'dbo:formerCoach']
# Querying for class http://dbpedia.org/ontology/Fish
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FootballMatch
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Governor
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HistoricBuilding
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HockeyTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Locomotive
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MilitaryUnit
# Results found: 28
# accepted properties: ['dbo:commandStructure', 'dbo:garrison']
# Querying for class http://dbpedia.org/ontology/MountainRange
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Murderer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Musical
# Results found: 1
# accepted properties: ['dbo:musicBy']
# Querying for class http://dbpedia.org/ontology/Painter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Place
# Results found: 15
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Politician
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Presenter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RugbyPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoccerClubSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoccerTournament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TelevisionShow
# Results found: 7
# accepted properties: ['dbo:numberOfEpisodes', 'dbo:numberOfSeasons']
# Querying for class http://dbpedia.org/ontology/Tunnel
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Volcano
# Results found: 1
# accepted properties: ['dbo:eruptionYear']
# Querying for class http://dbpedia.org/ontology/Winery
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HandballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Hotel
# Results found: 5
# accepted properties: ['dbo:numberOfRooms']
# Querying for class http://dbpedia.org/ontology/SnookerPlayer
# Results found: 7
# accepted properties: ['dbo:highestRank', 'dbo:centuryBreaks', 'dbo:bestFinish', 'dbo:highestBreak']
# Querying for class http://dbpedia.org/ontology/MotorcycleRacingLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SoftballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/InlineHockeyLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/NationalFootballLeagueSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RollerCoaster
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AmericanFootballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Architect
# Results found: 2
# accepted properties: ['dbo:significantBuilding']
# Querying for class http://dbpedia.org/ontology/Artery
# Results found: 1
# accepted properties: ['dbo:supplies']
# Querying for class http://dbpedia.org/ontology/AustralianFootballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BasketballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BiologicalDatabase
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bone
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Book
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bridge
# Results found: 7
# accepted properties: ['dbo:crosses', 'dbo:bridgeCarries']
# Querying for class http://dbpedia.org/ontology/ChessPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Comedian
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Conifer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CultivatedVariety
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CyclingRace
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Grape
# Results found: 2
# accepted properties: ['dbo:wineRegion']
# Querying for class http://dbpedia.org/ontology/Judge
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Monarch
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MusicalArtist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Nerve
# Results found: 1
# accepted properties: ['dbo:innervates']
# Querying for class http://dbpedia.org/ontology/PrimeMinister
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PublicTransitSystem
# Results found: 3
# accepted properties: ['dbo:numberOfLines']
# Querying for class http://dbpedia.org/ontology/Religious
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Road
# Results found: 4
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Royalty
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Skier
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Year
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/YearInSpaceflight
# Results found: 9
# accepted properties: ['dbo:orbitalFlights', 'dbo:countryWithFirstSatellite', 'dbo:maidenFlightRocket', 'dbo:totalTravellers', 'dbo:retiredRocket', 'dbo:countryWithFirstAstronaut']
# Querying for class http://dbpedia.org/ontology/Racecourse
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VolleyballCoach
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HandballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Actor
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AutomobileEngine
# Results found: 21
# accepted properties: ['dbo:displacement', 'dbo:automobileModel', 'dbo:configuration', 'dbo:startYearOfInsertion']
# Querying for class http://dbpedia.org/ontology/BusCompany
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Colour
# Results found: 11
# accepted properties: ['dbo:cmykCoordinateBlack', 'dbo:cmykCoordinateCyanic', 'dbo:cmykCoordinateMagenta', 'dbo:rgbCoordinateRed', 'dbo:cmykCoordinateYellow', 'dbo:hsvCoordinateSaturation', 'dbo:rgbCoordinateGreen', 'dbo:rgbCoordinateBlue', 'dbo:hsvCoordinateValue', 'dbo:hsvCoordinateHue']
# Querying for class http://dbpedia.org/ontology/Currency
# Results found: 1
# accepted properties: ['dbo:usingCountry']
# Querying for class http://dbpedia.org/ontology/Drug
# Results found: 3
# accepted properties: ['dbo:iupacName']
# Querying for class http://dbpedia.org/ontology/Earthquake
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FashionDesigner
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Fungus
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Glacier
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GovernmentAgency
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Guitarist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Historian
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Holiday
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Lighthouse
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MotorcycleRider
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Museum
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Newspaper
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Park
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PoliticalParty
# Results found: 8
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Rocket
# Results found: 7
# accepted properties: ['dbo:countryOrigin', 'dbo:maidenFlight', 'dbo:rocketStages', 'dbo:finalFlight', 'dbo:rocketFunction']
# Querying for class http://dbpedia.org/ontology/Senator
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ChemicalElement
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Cycad
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Entomologist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/WrestlingEvent
# Results found: 2
# accepted properties: ['dbo:promotion']
# Querying for class http://dbpedia.org/ontology/MouseGene
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AmericanFootballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AmericanFootballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AnimangaCharacter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Award
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BasketballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BasketballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CanadianFootballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Cardinal
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ComicsCharacter
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ComicsCreator
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Constellation
# Results found: 2
# accepted properties: ['dbo:neighbourConstellations', 'dbo:declination']
# Querying for class http://dbpedia.org/ontology/Cyclist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Engine
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FloweringPlant
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GaelicGamesPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Game
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MountainPass
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MythologicalFigure
# Results found: 1
# accepted properties: ['dbo:mythology']
# Querying for class http://dbpedia.org/ontology/Olympics
# Results found: 2
# accepted properties: ['dbo:numberOfParticipatingAthletes', 'dbo:numberOfParticipatingNations']
# Querying for class http://dbpedia.org/ontology/President
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RadioStation
# Results found: 1
# accepted properties: ['dbo:facilityId']
# Querying for class http://dbpedia.org/ontology/SoccerLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SupremeCourtOfTheUnitedStatesCase
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TelevisionStation
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Town
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Writer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Surname
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Train
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Canoeist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HumanGene
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MusicFestival
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/WomensTennisAssociationTournament
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AutoRacingLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ResearchProject
# Results found: 4
# accepted properties: ['dbo:projectParticipant', 'dbo:projectBudgetTotal', 'dbo:projectCoordinator']
# Querying for class http://dbpedia.org/ontology/LacrossePlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Ambassador
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AmusementParkAttraction
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bacteria
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Bank
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BodyOfWater
# Results found: 5
# accepted properties: ['dbo:inflow']
# Querying for class http://dbpedia.org/ontology/ChristianBishop
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Congressman
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Device
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Ginkgo
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/IceHockeyLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Library
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MartialArtist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MilitaryConflict
# Results found: 6
# accepted properties: ['dbo:combatant', 'dbo:place', 'dbo:isPartOfMilitaryConflict', 'dbo:causalties', 'dbo:result', 'dbo:strength']
# Querying for class http://dbpedia.org/ontology/Organisation
# Results found: 11
# accepted properties: ['dbo:formationYear', 'dbo:leaderFunction', 'dbo:headquarter']
# Querying for class http://dbpedia.org/ontology/Prison
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Protein
# Results found: 6
# accepted properties: ['dbo:refseq', 'dbo:chromosome', 'dbo:band']
# Querying for class http://dbpedia.org/ontology/RacingDriver
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RailwayLine
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Reptile
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Saint
# Results found: 9
# accepted properties: ['dbo:veneratedIn', 'dbo:majorShrine']
# Querying for class http://dbpedia.org/ontology/SiteOfSpecialScientificInterest
# Results found: 2
# accepted properties: ['dbo:areaOfSearch', 'dbo:interest']
# Querying for class http://dbpedia.org/ontology/SpaceShuttle
# Results found: 12
# accepted properties: ['dbo:lastFlightStartDate', 'dbo:lastFlightEndDate', 'dbo:missions']
# Querying for class http://dbpedia.org/ontology/Species
# Results found: 11
# accepted properties: ['dbo:family', 'dbo:kingdom', 'dbo:order', 'dbo:genus', 'dbo:phylum']
# Querying for class http://dbpedia.org/ontology/SportsLeague
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TelevisionEpisode
# Results found: 4
# accepted properties: ['dbo:episodeNumber', 'dbo:seasonNumber', 'dbo:guest']
# Querying for class http://dbpedia.org/ontology/Website
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ArchitecturalStructure
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Garden
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SumoWrestler
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TennisLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HorseRider
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SpeedwayTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VideogamesLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Skyscraper
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SpeedwayRider
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GrandPrix
# Results found: 17
# accepted properties: ['dbo:firstDriverTeam', 'dbo:poleDriverTeam', 'dbo:thirdTeam', 'dbo:course', 'dbo:fastestDriverTeam', 'dbo:fastestDriver', 'dbo:thirdDriver', 'dbo:distanceLaps', 'dbo:poleDriver', 'dbo:secondDriver', 'dbo:firstDriver', 'dbo:secondTeam']
# Querying for class http://dbpedia.org/ontology/NationalCollegiateAthleticAssociationAthlete
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Astronaut
# Results found: 1
# accepted properties: ['dbo:selection']
# Querying for class http://dbpedia.org/ontology/BaseballPlayer
# Results found: 5
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BeautyQueen
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Brain
# Results found: 4
# accepted properties: ['dbo:brainInfoType', 'dbo:brainInfoNumber']
# Querying for class http://dbpedia.org/ontology/Chancellor
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/City
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/College
# Results found: 1
# accepted properties: ['dbo:sisterCollege']
# Querying for class http://dbpedia.org/ontology/Curler
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Enzyme
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GivenName
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GolfLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HistoricPlace
# Results found: 4
# accepted properties: ['dbo:added', 'dbo:nrhpReferenceNumber']
# Querying for class http://dbpedia.org/ontology/HorseRace
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MilitaryStructure
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/NascarDriver
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/OfficeHolder
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/OlympicResult
# Results found: 8
# accepted properties: ['dbo:numberOfCompetitors', 'dbo:flagBearer', 'dbo:games', 'dbo:rankInFinalMedalCount']
# Querying for class http://dbpedia.org/ontology/PersonFunction
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PlayboyPlaymate
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ProgrammingLanguage
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ProtectedArea
# Results found: 1
# accepted properties: ['dbo:iucnCategory']
# Querying for class http://dbpedia.org/ontology/RaceHorse
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Skater
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SportsTeamMember
# Results found: 1
# accepted properties: ['dbo:squadNumber']
# Querying for class http://dbpedia.org/ontology/TelevisionHost
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TennisPlayer
# Results found: 2
# accepted properties: ['dbo:careerPrizeMoney', 'dbo:plays']
# Querying for class http://dbpedia.org/ontology/Theatre
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Venue
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Wrestler
# Results found: 2
# accepted properties: ['dbo:billed']
# Querying for class http://dbpedia.org/ontology/WrittenWork
# Results found: 6
# accepted properties: ['dbo:literaryGenre', 'dbo:mediaType']
# Querying for class http://dbpedia.org/ontology/Priest
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Singer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/DartsPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Lymph
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Moss
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SnookerChamp
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SquashPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TelevisionSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HumanGeneLocation
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AcademicConference
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BeachVolleyballPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Rower
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/WaterwayTunnel
# Results found: 1
# accepted properties: ['dbo:waterwayThroughTunnel']
# Querying for class http://dbpedia.org/ontology/MixedMartialArtsLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CricketLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CyclingTeam
# Results found: 1
# accepted properties: ['dbo:uciCode']
# Querying for class http://dbpedia.org/ontology/HandballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Beverage
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CanadianFootballTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Canal
# Results found: 14
# accepted properties: ['dbo:hasJunctionWith', 'dbo:endPoint', 'dbo:startPoint']
# Querying for class http://dbpedia.org/ontology/Cheese
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Chef
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Comic
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Cricketer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Dam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Fern
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Jockey
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/LacrosseLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Manga
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Medician
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MilitaryPerson
# Results found: 6
# accepted properties: ['dbo:militaryBranch', 'dbo:militaryCommand', 'dbo:serviceEndYear', 'dbo:serviceStartYear', 'dbo:militaryUnit']
# Querying for class http://dbpedia.org/ontology/Mountain
# Results found: 4
# accepted properties: ['dbo:mountainRange']
# Querying for class http://dbpedia.org/ontology/Muscle
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/OlympicEvent
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Person
# Results found: 53
# accepted properties: ['dbo:birthDate', 'dbo:careerStation', 'dbo:birthPlace', 'dbo:deathDate']
# Querying for class http://dbpedia.org/ontology/Photographer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Planet
# Results found: 12
# accepted properties: ['dbo:epoch', 'dbo:orbitalPeriod', 'dbo:rotationPeriod']
# Querying for class http://dbpedia.org/ontology/RadioHost
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Ship
# Results found: 14
# accepted properties: ['dbo:shipLaunch', 'dbo:shipBeam', 'dbo:commissioningDate']
# Querying for class http://dbpedia.org/ontology/ShoppingMall
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SportsEvent
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Village
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/WineRegion
# Results found: 6
# accepted properties: ['dbo:growingGrape', 'dbo:varietals', 'dbo:isPartOfWineRegion']
# Querying for class http://dbpedia.org/ontology/WorldHeritageSite
# Results found: 1
# accepted properties: ['dbo:id']
# Querying for class http://dbpedia.org/ontology/MixedMartialArtsEvent
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Farmer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BadmintonPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Baronet
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Novel
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SpeedwayLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CricketGround
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/EurovisionSongContestEntry
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Stream
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VolleyballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/LaunchPad
# Results found: 7
# accepted properties: ['dbo:numberOfPads', 'dbo:associatedRocket']
# Querying for class http://dbpedia.org/ontology/Arachnid
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Athlete
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BaseballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Castle
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Cave
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ChemicalCompound
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Country
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Economist
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Film
# Results found: 4
# accepted properties: ['dbo:cinematography', 'dbo:director']
# Querying for class http://dbpedia.org/ontology/FormulaOneTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Gnetophytes
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/HollywoodCartoon
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/InformationAppliance
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Island
# Results found: 9
# accepted properties: ['dbo:archipelago']
# Querying for class http://dbpedia.org/ontology/Lake
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/MotorsportSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Noble
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RailwayTunnel
# Results found: 1
# accepted properties: ['dbo:railwayLineUsingTunnel']
# Querying for class http://dbpedia.org/ontology/River
# Results found: 12
# accepted properties: ['dbo:mouthPlace', 'dbo:mouthMountain', 'dbo:riverMouth']
# Querying for class http://dbpedia.org/ontology/Song
# Results found: 1
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Sound
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/SportsSeason
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Station
# Results found: 14
# accepted properties: ['dbo:servingRailwayLine', 'dbo:railwayPlatforms']
# Querying for class http://dbpedia.org/ontology/TimePeriod
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/VideoGame
# Results found: 2
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Lawyer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/CricketTeam
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Fashion
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Mayor
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/TableTennisPlayer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/AustralianFootballLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/PoloLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BoxingLeague
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Spacecraft
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Airport
# Results found: 6
# accepted properties: ['dbo:runwaySurface', 'dbo:icaoLocationIdentifier', 'dbo:runwayLength', 'dbo:runwayDesignation']
# Querying for class http://dbpedia.org/ontology/Amphibian
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/BroadcastNetwork
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ComicStrip
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/ConcentrationCamp
# Results found: 3
# accepted properties: ['dbo:liberationDate', 'dbo:numberOfDeaths']
# Querying for class http://dbpedia.org/ontology/Election
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/EthnicGroup
# Results found: 2
# accepted properties: ['dbo:populationPlace', 'dbo:totalPopulation']
# Querying for class http://dbpedia.org/ontology/Eukaryote
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FictionalCharacter
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FilmFestival
# Results found: 3
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/FormulaOneRacer
# Results found: 10
# accepted properties: ['dbo:firstRace', 'dbo:fastestLap', 'dbo:races', 'dbo:lastRace', 'dbo:championships', 'dbo:poles', 'dbo:podiums']
# Querying for class http://dbpedia.org/ontology/GolfPlayer
# Results found: 13
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/GreenAlga
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Gymnast
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Language
# Results found: 5
# accepted properties: ['dbo:iso6393Code', 'dbo:spokenIn', 'dbo:languageFamily']
# Querying for class http://dbpedia.org/ontology/Pope
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/RecordLabel
# Results found: 2
# accepted properties: ['dbo:distributingLabel', 'dbo:distributingCompany']
# Querying for class http://dbpedia.org/ontology/Restaurant
# Results found: 4
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Scientist
# Results found: 4
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Single
# Results found: 6
# accepted properties: ['dbo:bSide', 'dbo:musicalArtist', 'dbo:musicalBand']
# Querying for class http://dbpedia.org/ontology/Swimmer
# Results found: 0
# accepted properties: []
# Querying for class http://dbpedia.org/ontology/Weapon
# Results found: 1
# accepted properties: ['dbo:usedInWar']

# %%
len(class_propcov_map)
# Out:
# 421

# %%
len(xml_map)
# Out:
# 95

# %%
outfile_tmplt = './limes-cfg/porque_enrich_limes_config_%s_%s.xml'
predfile_tmplt = 'predictions_%s_%s.nt'
revfile_tmplt = 'predictions_rev_%s_%s.nt'
count = 1
for class_name in xml_map.keys():
    xml_obj = xml_map[class_name]
    count_str = str(count)
    # For each language (de/es/fr)
    for lang in ['de','fr','es']:
        # check their map for the class. If class exists, then create the config file for that language
        if (not class_name in crm_lang_map[lang]) or crm_lang_map[lang][class_name] == 0:
            continue
        file_name = outfile_tmplt%(lang, count)
        predfile = predfile_tmplt%(lang, count)
        revfile = revfile_tmplt%(lang, count)
        # change prediction and review file name
        xml_obj.getroot().find('ACCEPTANCE').find('FILE').text = predfile
        xml_obj.getroot().find('REVIEW').find('FILE').text = revfile
        # change the map for query
        target_graph = xml_obj.getroot().find('TARGET').find('GRAPH')
        target_graph.text = sparql_map[lang]._defaultGraph
        # Convert obj to string and write 
        # xmlstr = minidom.parseString(ET.tostring(xml_obj.getroot())).toprettyxml(indent="    ",encoding="utf-8")
        with open(file_name, "wb") as f:
            # f.write(xmlstr)
            f.write('<?xml version="1.0" encoding="utf-8"?>\n<!DOCTYPE LIMES SYSTEM "limes.dtd">\n'.encode('utf8'))
            ET.ElementTree(xml_obj.getroot()).write(f, 'utf-8')
    count+=1
print('Done')
# Out:
# Done

# %%
#
# Obsolete code
#

outfile_tmplt = '/data-disk/kg-fusion/limes-cfg/porque_enrich_limes_config_%s.xml'
predfile_tmplt = 'predictions_%s.nt'
revfile_tmplt = 'predictions_rev_%s.nt'
count = 1
for class_name in xml_map.keys():
    xml_obj = xml_map[class_name]
    count_str = str(count)
    file_name = outfile_tmplt%count
    predfile = predfile_tmplt%count
    revfile = revfile_tmplt%count
    # change prediction and review file name
    xml_obj.getroot().find('ACCEPTANCE').find('FILE').text = predfile
    xml_obj.getroot().find('REVIEW').find('FILE').text = revfile
    
    # Convert obj to string and write 
    xmlstr = minidom.parseString(ET.tostring(xml_obj.getroot())).toprettyxml(indent="    ",encoding="utf-8")
    with open(file_name, "wb") as f:
        f.write(xmlstr)
    count+=1
print('Done')
# Out:
# Done

# %%
# Scrap code snippets below

# %%
print(sample_file.getroot().find('SOURCE').find('ID').text)
# Out:
# en-dbpedia2016-10

# %%
source_ele = sample_file.getroot().find('SOURCE')
restriction = ET.Element('RESTRICTION')
restriction.text = '?x a <%s>'
source_ele.append(restriction)

# %%
for item in sample_file.getroot().find('SOURCE')
print(item.tag, item.text)
# Out:
#   File "<ipython-input-48-aa963a4be64b>", line 1
#     for item in sample_file.getroot().find('SOURCE')
#                                                     ^
# SyntaxError: invalid syntax
